# %%
# !pip install gensim matplotlib scikit-learn
# Out:
# Requirement already satisfied: gensim in c:\users\prajw\anaconda3\lib\site-packages (4.4.0)
# Requirement already satisfied: matplotlib in c:\users\prajw\anaconda3\lib\site-packages (3.10.6)
# Requirement already satisfied: scikit-learn in c:\users\prajw\anaconda3\lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\prajw\anaconda3\lib\site-packages (from gensim) (2.3.5)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\prajw\anaconda3\lib\site-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in c:\users\prajw\anaconda3\lib\site-packages (from gensim) (7.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\prajw\anaconda3\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\prajw\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\prajw\anaconda3\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\prajw\anaconda3\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\prajw\anaconda3\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\prajw\anaconda3\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\prajw\anaconda3\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\prajw\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\prajw\anaconda3\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\prajw\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\prajw\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: wrapt in c:\users\prajw\anaconda3\lib\site-packages (from smart_open>=1.8.1->gensim) (1.17.0)

# %%
"""
Use dimensionality reduction (e.g., PCA or t-SNE) to visualize word embeddings for Q 1. Select 10 words from a
specific domain (e.g., sports, technology) and visualize their embeddings. Analyze clusters and relationships.
Generate contextually rich outputs using embeddings. Write a program to generate 5 semantically similar words
for a given input.

"""
# Out:
# '\nUse dimensionality reduction (e.g., PCA or t-SNE) to visualize word embeddings for Q 1. Select 10 words from a\nspecific domain (e.g., sports, technology) and visualize their embeddings. Analyze clusters and relationships.\nGenerate contextually rich outputs using embeddings. Write a program to generate 5 semantically similar words\nfor a given input.\n\n'

# %%
import gensim.downloader as api
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
# Load model
model = api.load("word2vec-google-news-300")
# Select 10 domain-specific words (technology domain)
words = ['computer', 'internet', 'software', 'hardware', 'keyboard', 'mouse', 'server', 'network', 'programming', 'database']
vectors = [model[word] for word in words]
# Dimensionality reduction using PCA
pca = PCA(n_components=2)
reduced = pca.fit_transform(vectors)
# Plot the word embeddings
plt.figure(figsize=(8, 6))
for i, word in enumerate(words):
    plt.scatter(reduced[i, 0], reduced[i, 1])
    plt.annotate(word, (reduced[i, 0], reduced[i, 1]))
plt.title("PCA Visualization of Technology Word Embeddings")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.grid(True)
# Show the plot
plt.show()

# %%
import plotly.express as px
import pandas as pd

# Prepare a DataFrame for Plotly
df = pd.DataFrame({
    "PC1": reduced[:, 0],
    "PC2": reduced[:, 1],
    "word": words
})

# Create interactive scatter plot
fig = px.scatter(
    df,
    x="PC1",
    y="PC2",
    text="word",          # show word labels on points
    hover_data=["PC1","PC2"],  # hover shows coordinates
    title="PCA Visualization of Technology Word Embeddings"
)

# Adjust text position slightly above the point
fig.update_traces(textposition='top center')

# Show the interactive plot
fig.show()

# %%
# Generate 5 semantically similar words for a given input
input_word = 'computer'
similar_words = model.most_similar(input_word, topn=5)

# %%
# Print the similar words to terminal
print(f"Top 5 words similar to '{input_word}':")
for word, score in similar_words:
    print(f"{word}: {score:.4f}")
# Out:
# Top 5 words similar to 'computer':
# computers: 0.7979
# laptop: 0.6640
# laptop_computer: 0.6549
# Computer: 0.6473
# com_puter: 0.6082

# %%
# Select 10 domain-specific words (technology domain)
words = ['computer', 'internet', 'software', 'hardware', 'keyboard', 'mouse', 'server', 'network', 'programming', 'database']
vectorsg = [model[word] for word in words]

# %%
# Dimensionality reduction using PCA
pca = PCA(n_components=2)
reducedg = pca.fit_transform(vectorsg)

# %%
# Plot the word embeddings
plt.figure(figsize=(8, 6))
for i, word in enumerate(words):
    plt.scatter(reducedg[i, 0], reducedg[i, 1])
    plt.annotate(word, (reducedg[i, 0], reducedg[i, 1]))
plt.title("PCA Visualization of Technology Word Embeddings")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.grid(True)
# Show the plot
plt.show()

# %%
# Generate 5 semantically similar words for a given input
input_word = 'computer'
similar_words = model.most_similar(input_word, topn=5)

# %%
# Print the similar words to terminal
print(f"Top 5 words similar to '{input_word}':")
for word, score in similar_words:
    print(f"{word}: {score:.4f}")
# Out:
# Top 5 words similar to 'computer':
# computers: 0.7979
# laptop: 0.6640
# laptop_computer: 0.6549
# Computer: 0.6473
# com_puter: 0.6082
